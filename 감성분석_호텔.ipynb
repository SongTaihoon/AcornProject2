# %%
# 기본
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 경고 뜨지 않게 설정
import warnings
warnings.filterwarnings('ignore')

# 그래프 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
# plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['font.size'] = 16
plt.rcParams['figure.figsize'] = 20, 10
plt.rcParams['axes.unicode_minus'] = False

# 데이터 전처리 알고리즘
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# 학습용과 검증용으로 나누는 함수
from sklearn.model_selection import train_test_split

# 교차 검증
# 지표를 하나만 설정할 경우
from sklearn.model_selection import cross_val_score
# 지표를 하나 이상 설정할 경우
from sklearn.model_selection import cross_validate
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold

# 모델의 최적의 하이퍼파라미터를 찾기 위한 도구
from sklearn.model_selection import GridSearchCV

# 평가함수
# 분류용
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score

# 회귀용
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# 머신러닝 알고리즘 - 분류
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import VotingClassifier

# 머신러닝 알고리즘 - 회귀
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import VotingRegressor

# 차원축소
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# 군집화
from sklearn.cluster import KMeans
from sklearn.cluster import MeanShift
from sklearn.cluster import estimate_bandwidth



# ARIMA (시계열 예측)
from statsmodels.tsa.arima_model import ARIMA
import statsmodels.api as sm


# 시간 측정을 위한 시간 모듈
import datetime

# 주식정보
from pandas_datareader import data

# 형태소 벡터를 생성하기 위한 라이브러리
from sklearn.feature_extraction.text import CountVectorizer
# 형태소 벡터를 학습 벡터로 변환한다.
from sklearn.feature_extraction.text import TfidfTransformer


# 데이터 수집
import requests
from bs4 import BeautifulSoup
import re
import time
import os
import json

# 한국어 형태소 분석
from konlpy.tag import Okt, Hannanum, Kkma, Mecab, Komoran

# 워드 클라우드를 위한 라이브러리
from collections import Counter
import pytagcloud
from IPython.display import Image

# 저장
import pickle
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.9.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
df = pd.read_csv('./hotel.csv', sep=',', encoding='cp949')
okt=Okt()
ii=[]
AA=[]
BB=[]
CC=[]
DD=[]
EE=[]
FF=[]
GG=[]
AA_1=[]

for i in range(len(df)):
    AA.append(df.iloc[i,4]) #리뷰
    AA_1.append(df.iloc[i,4]) #리뷰원본
    BB.append(df.iloc[i,2]) #리뷰어
    CC.append(df.iloc[i,3]) #제목
    DD.append(df.iloc[i,0]) #숙소이름
    EE.append(df.iloc[i,6]) #개인평점
    FF.append(df.iloc[i,13]) #권역
    GG.append(df.iloc[i,5]) #동행여부
    
for i in range(len(AA)):
    AA[i]=re.sub("[^ㄱ-ㅎㅏ-ㅣ가-힣]","",AA[i])
    AA[i]=okt.morphs(AA[i],norm=True,stem=True)
    AA[i]=[x for x in AA[i] if len(x)>1]
    AA[i]=' '.join(AA[i])
    
hotel_df1=pd.DataFrame({'review':AA,'ID':BB,'title':CC,'place':DD,'rating':EE,'region':FF,'company':GG,'raw':AA_1})

hangul = re.compile('[ㄱ-ㅣ가-힣]+')

for i in range(len(hotel_df1)):
    if len(hangul.findall(hotel_df1.iloc[i,0]))>1:
        if len(hotel_df1.iloc[i,0])>1:
            ii.append(i)

# %%
hotel_df2=hotel_df1.iloc[ii,:]
hotel_df2.to_csv('hotelnoun.csv',index=False, encoding='cp949')
hotel_df2.head()
# Out:
#                                               review                   ID  \
# 0  숙박 하다 바다 하다 처음 방향 으로 잡다 바로 도로 건너편 자리 개다 찝찝하다 덥...  Passport09376479346
# 1  조용하다 깔끔하다 바다 전망 호텔 이다 가격 대비 매우 만족스럽다 이다 인근 센터 ...                  쫑아리
# 2  제주시 인근 위치 하고 있다 오션 뷰룸 경우 탁트인 전망 즐기다 아침 식도 필요하다...        Sang-Yoll Kim
# 3  공항 에서 멀다 않다 조용하다 머무르다 추천 드리다 시설 깨끗하다 아주 좋다 가격 ...             jiyoun_K
# 4  깨끗하다 좋다 오션 좋다 화장실 깨끗 생각 보다 식이 맛있다 주차 자리 없다 직원 ...                 나나랜드
#
#                title         place  rating  region          company  \
# 0         바다뷰는 좋으나..  탐라 스테이 호텔 제주      20       4  여행 유형: 나 혼자 여행함
# 1     가성비 좋은 바다전망 호텔  탐라 스테이 호텔 제주      50       4   여행 유형: 가족과 여행함
# 2     한적한 곳에서 편안한 휴식  탐라 스테이 호텔 제주      50       4   여행 유형: 가족과 여행함
# 3  공항에서 멀지 않고 뷰도 좋아요  탐라 스테이 호텔 제주      40       4
# 4           이틀 묵었는데   탐라 스테이 호텔 제주      40       4
#
#                                                  raw
# 0  이곳에 숙박하실려면 꼭 바다뷰로 하세요.처음 산 방향으로 방을 잡았는데,바로 앞 도...
# ...

# %%
hotel_df1.head()
# Out:
#                                               review                   ID  \
# 0  숙박 하다 바다 하다 처음 방향 으로 잡다 바로 도로 건너편 자리 개다 찝찝하다 덥...  Passport09376479346
# 1  조용하다 깔끔하다 바다 전망 호텔 이다 가격 대비 매우 만족스럽다 이다 인근 센터 ...                  쫑아리
# 2  제주시 인근 위치 하고 있다 오션 뷰룸 경우 탁트인 전망 즐기다 아침 식도 필요하다...        Sang-Yoll Kim
# 3  공항 에서 멀다 않다 조용하다 머무르다 추천 드리다 시설 깨끗하다 아주 좋다 가격 ...             jiyoun_K
# 4  깨끗하다 좋다 오션 좋다 화장실 깨끗 생각 보다 식이 맛있다 주차 자리 없다 직원 ...                 나나랜드
#
#                title         place  rating  region          company  \
# 0         바다뷰는 좋으나..  탐라 스테이 호텔 제주      20       4  여행 유형: 나 혼자 여행함
# 1     가성비 좋은 바다전망 호텔  탐라 스테이 호텔 제주      50       4   여행 유형: 가족과 여행함
# 2     한적한 곳에서 편안한 휴식  탐라 스테이 호텔 제주      50       4   여행 유형: 가족과 여행함
# 3  공항에서 멀지 않고 뷰도 좋아요  탐라 스테이 호텔 제주      40       4
# 4           이틀 묵었는데   탐라 스테이 호텔 제주      40       4
#
#                                                  raw
# 0  이곳에 숙박하실려면 꼭 바다뷰로 하세요.처음 산 방향으로 방을 잡았는데,바로 앞 도...
# ...

# %%
#단어 빈도 추출 - 카테고리 생성(객실/가격/위치/서비스/청결/침구)
A=hotel_df2.review.to_list()
B=[]
for i in range(len(A)):
    B+=A[i].split(' ')
    
words_count={}
for word in B:
    if word in words_count:
        words_count[word] += 1
    else:
        words_count[word] = 1
sorted_words = sorted([(k,v) for k,v in words_count.items()], key=lambda word_count: -word_count[1])
print([w[0]for w in sorted_words])
# Out:
# ['하다', '좋다', '호텔', '있다', '이다', '에서', '너무', '직원', '으로', '않다', '시설', '친절하다', '객실', '없다', '여행', '되다', '같다', '깨끗하다', '오다', '보다', '가족', '많다', '위치', '되어다', '하고', '제주', '가다', '방문', '수영장', '이용', '서비스', '가격', '매우', '제주도', '조식', '정말', '넓다', '공항', '아이', '깔끔하다', '자다', '분들', '용하다', '해주다', '리조트', '생각', '다음', '까지', '침대', '체크', '이라', '들다', '에는', '편하다', '신화', '시간', '아쉽다', '숙소', '먹다', '예약', '바다', '에도', '가깝다', '추천', '최고', '크다', '만족하다', '다른', '정도', '주변', '아니다', '편안하다', '조금', '거리', '맛있다', '만족스럽다', '월드', '아주', '우리', '괜찮다', '받다', '근처', '묵다', '숙박', '느낌', '많이', '컨디션', '특히', '음식', '싶다', '그리고', '불편하다', '투숙', '함께', '즐기다', '이나', '모든', '바로', '식당', '편리하다', '때문', '그렇다', '모두', '보이다', '선택', '전망', '주차', '사람', '훌륭하다', '다시', '화장실', '편의점', '전반', '또한', '처음', '조용하다', '아침', '안되다', '상태', '감사하다', '기분', '제공', '보내다', '무료', '로비', '찾다', '쉬다', '놀다', '부터', '즐겁다', '욕실', '인데', '다만', '저렴하다', '가능하다', '청소', '없이', '좋아하다', '수영', '대비', '저녁', '레스토랑', '마음', '워터파크', '장이', '침구', '에게', '롯데', '넘다', '이번', '신라', '뷔페', '지내다', '늘다', '부대', '파크', '다양하
# ...

# %%
#Word2Vec 카테고리별 코사인 유사도가 높은 단어 구하기
X=[[]]*len(hotel_df2)
for i in range(len(hotel_df2)):
    X[i] = hotel_df2.iloc[i,0].split(' ')

from gensim.models import Word2Vec
model_w = Word2Vec(sentences=X,vector_size=500,window=5,min_count=2,workers=4,sg=1)

# %%
noum1=pd.DataFrame(model_w.wv.most_similar('객실',topn=20),columns=['단어','객실'])
noum2=pd.DataFrame(model_w.wv.most_similar('가격',topn=20),columns=['단어','가격'])
noum3=pd.DataFrame(model_w.wv.most_similar('위치',topn=20),columns=['단어','위치'])
noum4=pd.DataFrame(model_w.wv.most_similar('서비스',topn=20),columns=['단어','서비스'])
noum5=pd.DataFrame(model_w.wv.most_similar('청결',topn=20),columns=['단어','청결'])
noum6=pd.DataFrame(model_w.wv.most_similar('침구',topn=20),columns=['단어','침구'])

# %%
A=list(set(noum1.단어.tolist()+noum2.단어.tolist()+noum3.단어.tolist()+noum4.단어.tolist()+noum5.단어.tolist()+noum6.단어.tolist()))
A=sorted(A)
pd.DataFrame(A).to_csv('hotelnoumlist.csv',index=False, encoding='utf-8-sig')

# %%
#카테고리-단어 코사인유사도행렬 구하기
A=pd.read_csv('./hotelnoumlist.csv',sep=',',encoding='utf-8-sig')
A=A.iloc[:,0].tolist()
A=sorted(A)

B_객실=[]
B_가격=[]
B_위치=[]
B_서비스=[]
B_청결=[]
B_침구=[]
for i in range(len(A)):
    B_객실.append(model_w.wv.similarity('객실',A[i]))
    B_가격.append(model_w.wv.similarity('가격',A[i]))
    B_위치.append(model_w.wv.similarity('위치',A[i]))
    B_서비스.append(model_w.wv.similarity('서비스',A[i]))
    B_청결.append(model_w.wv.similarity('청결',A[i]))
    B_침구.append(model_w.wv.similarity('침구',A[i]))
B_total = pd.DataFrame({'객실':B_객실,'가격':B_가격,'위치':B_위치,'서비스':B_서비스,'청결':B_청결,'침구':B_침구}).transpose()
B_total.columns=[A]
B_total[B_total<0.7]=0
B_total.to_csv('hotelnoumlist2.csv',index=False, encoding='utf-8-sig')

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer()
for i in range(len(X)):
    globals()['val_{}'.format(i)]=[]
B=[]
for i in range(len(X)):
    for j in X[i]:
        if j in A:
            globals()['val_{}'.format(i)].append(j)
            B.append(i)
C=[]
for j in range(len(X)):
    if j not in list(set(B)):
        C.append('')
    else:
        C.append(' '.join(globals()['val_{}'.format(j)]))
TDM_array=cv.fit_transform(C).toarray()
feature_names=cv.get_feature_names()
TDM_DataFrame=pd.DataFrame(TDM_array,columns=feature_names)

# %%
#카테고리별 리뷰 연관성 파악
Result = B_total.to_numpy() @TDM_DataFrame.transpose().to_numpy()
round(pd.DataFrame(Result),4).to_csv('relationhotelresult.csv', encoding='utf-8-sig')
B_total.to_csv('wordhotelresult.csv', encoding='utf-8-sig')
TDM_DataFrame.to_csv('TDMhotelresult.csv', encoding='utf-8-sig')

# %%
#감성사전
dict=pd.read_csv('./word.csv',sep=',',encoding='cp949')

# %%
X=[[]]*len(hotel_df2)
for i in range(len(hotel_df2)):
    X[i] = hotel_df2.iloc[i,0].split(' ')

#감성점수부여
A=[0]*len(hotel_df2)
B=[0]*len(hotel_df2)
C=[0]*len(hotel_df2)
for i in range(len(hotel_df2)):
    for j in range(len(X[i])):
        if X[i][j] in dict.word.tolist():
            A[i]+=dict.polarity.tolist()[dict.word.tolist().index(X[i][j])]
            B[i]+=1
for i in range(len(C)):
    if B[i]!=0:
        C[i]=round(int(A[i])/int(B[i]),2)
hotel_df2['감성점수']=C
hotel_df2.to_csv('hotelfinal.csv',index=False,encoding='cp949')
